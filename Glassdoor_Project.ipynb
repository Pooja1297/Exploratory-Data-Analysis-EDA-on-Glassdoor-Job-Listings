# %% [markdown]
# <a href="https://colab.research.google.com/github/Pooja1297/Exploratory-Data-Analysis-EDA-on-Glassdoor-Job-Listings/blob/main/Glassdoor_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name** : Exploratory Data Analysis (EDA) on Glassdoor Job Listings

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name -** Pooja Sharma

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
#  **Exploratory Data Analysis (EDA) on Jobs from Glassdoor (2017)**
#
#  The aim of this project is to perform an exploratory data analysis (EDA) on a dataset of job listings from Glassdoor in 2017.
#
#  **Dataset Overview** :
# The dataset contains information about various job listings on Glassdoor in 2017. Key attributes in the dataset include:
#
# - Job titles
#
# - Company names
#
# - Salary estimates
#
# - Job locations (cities, states, and countries)
#
# - Job descriptions
#
# - Required skills
#
# - Education levels
#
# - Experience levels
#
# - Industry and job categories
#
# **Key Steps in EDA** :
#
# **1. Data Cleaning and Preprocessing** :
#
# - Handling missing or inconsistent values.
#
# - Conversion of data types for easier analysis (e.g., salary data, date-related attributes).
#
# - Standardizing categorical variables (e.g., job categories, company names).
#
# **2. Summary Statistics** :
#
# - Descriptive statistics to summarize the data.
#
# - Identify the distribution of salaries, experience levels, education requirements, and other numerical attributes.
#
# **3. Data Visualizations** :
#
#
# **- Salary Distribution** : A breakdown of salary distributions by job category, location, and experience level.
#
# **- Most Common Job Titles** : Visualization of the most common job titles and their frequency.
#
# **- Company Overview** : Analysis of the most prominent companies hiring, including a count of job openings.
#
# **- Geographical Patterns** : Mapping job distribution by location and analyzing salary variations across regions or cities.
#
# **- Skills Demand** : Identifying the most common required skills and their trends across industries and job roles.
#
# **4. Job Trends Over Time** :
#
#
# - Examining job demand trends across industries, including job category shifts and regional variations.
#
# - Identifying the emergence of new roles and the decline of certain traditional roles.
#
# **5. Correlation and Insights** :
#
# - Investigating the relationship between salary and job requirements such as education level, experience, and location.
#
# - Identifying correlations between job satisfaction ratings and other job features.
#
#
# **Expected Insights** :
#
# **Salary Insights** : Discover salary patterns and how they vary across industries, locations, and experience levels.
#
# **Job Market Trends** : Understand the most in-demand job titles and skills, and the shifting demands across various regions.
#
# **Regional Insights** : Identify which locations offer the best job opportunities and highest salaries.
#
# **Skills and Education Trends** : Uncover which skills are most in-demand and the education levels associated with those positions.
#
# **Company Analysis** : Learn about the most active hiring companies and industries.
#
#
# **Tools and Technologies Used** :
#
# **Data Cleaning and Preprocessing** : Pandas, NumPy
#
# **Exploratory Data Analysis** : Matplotlib, Seaborn

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# 1. How does salary vary by job position (e.g., Data Scientist vs. Software Engineer vs. DevOps Engineer)?
#
# 2.  What is the impact of company size on salary levels?
# • How do salaries differ by location (e.g., San Francisco vs. Austin vs. New York)?
#
# 3.  Can we build a predictive model to estimate salaries based on job attributes?
# By analyzing this dataset, we can predict salary ranges, uncover market trends, and provide insights to tech professionals and organizations.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The objective is to uncover insights about the job market in terms of trends, salary expectations, job categories, location-based patterns, and other significant factors that could help job seekers, employers, and data scientists understand the structure and dynamics of the job market.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
df = pd.read_csv('/content/glassdoor_jobs.csv')

# %% [markdown]
# ### Dataset First View

# %%
df.head()
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.shape
# Out:
# (956, 15)

# %% [markdown]
# ### Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         956 non-null    int64
#  1   Job Title          956 non-null    object
#  2   Salary Estimate    956 non-null    object
#  3   Job Description    956 non-null    object
#  4   Rating             956 non-null    float64
#  5   Company Name       956 non-null    object
#  6   Location           956 non-null    object
#  7   Headquarters       956 non-null    object
#  8   Size               956 non-null    object
#  9   Founded            956 non-null    int64
#  10  Type of ownership  956 non-null    object
#  11  Industry           956 non-null    object
#  12  Sector             956 non-null    object
#  13  Revenue            956 non-null    object
#  14  Competitors        956 non-null    object
# dtypes: float64(1), int64(2), object(12)
# ...

# %% [markdown]
# #### Duplicate Values

# %%
duplicate_count = df.duplicated().sum()

print(duplicate_count)
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# dtype: int64

# %%
# Visualizing the missing values
# Removing Unwanted Data

df.drop(columns="Unnamed: 0",inplace=True)

# %%
# Drop rows where Sector is -1
df = df[df["Sector"] != "-1"]

# Confirm changes
print(df["Sector"].unique())  # Check remaining unique sector values
# Out:
# ['Aerospace & Defense' 'Health Care' 'Business Services'
#  'Oil, Gas, Energy & Utilities' 'Real Estate' 'Finance'
#  'Information Technology' 'Retail' 'Biotech & Pharmaceuticals' 'Media'
#  'Insurance' 'Transportation & Logistics' 'Manufacturing'
#  'Telecommunications' 'Mining & Metals' 'Government' 'Education'
#  'Agriculture & Forestry' 'Travel & Tourism' 'Non-Profit'
#  'Arts, Entertainment & Recreation' 'Construction, Repair & Maintenance'
#  'Accounting & Legal' 'Consumer Services']

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Data Set contains Job Title, Salary Estimate, Job Description, Rating, Company Name, Location, Headquarters, Size, Founded, Type of ownership, Industry, Sector, Revenue, and Competitors. This Dataset does not have any kind of null values and duplicate data.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#            Rating      Founded
# count  917.000000   917.000000
# mean     3.753326  1850.122137
# std      0.681751   483.800387
# min     -1.000000    -1.000000
# 25%      3.400000  1958.000000
# 50%      3.800000  1995.000000
# 75%      4.200000  2008.000000
# max      5.000000  2019.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Job Title**: The name or title of the job being listed.
#
# **Salary Estimate**: The estimated salary range for the job position.
#
# **Job Description**: A detailed description of the job, including responsibilities and requirements.
#
# **Rating**: The rating of the company, possibly from employee reviews or other rating sources.
#
# **Company Name**: The name of the company offering the job.
#
# **Location**: The location where the job is based.
#
# **Headquarters**: The headquarters location of the company.
#
# **Size**: The size of the company, often in terms of the number of employees (e.g., 1-50, 51-200).
#
# **Founded**: The year the company was founded.
#
# **Type of ownership**: The type of ownership of the company (e.g., Public, Private, Government).
#
# **Industry**: The industry in which the company operates (e.g., Technology, Healthcare).
#
# **Sector**: The broader sector within the industry (e.g., Information Technology, Financial Services).
#
# **Revenue**: The revenue of the company, often in terms of annual revenue.
#
# **Competitors**: A list of companies that compete with this company.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable

unique_counts = df.nunique()
print(unique_counts)
# Out:
# Job Title            318
# Salary Estimate      413
# Job Description      572
# Rating                32
# Company Name         427
# Location             232
# Headquarters         226
# Size                   8
# Founded              109
# Type of ownership     12
# Industry              62
# Sector                24
# Revenue               13
# Competitors          149
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
#replacing -1 with Nan to identify the NUll Values, inplace is used to modify existing
df.replace('-1',np.nan,inplace=True)

#counting the number of null values
df.isnull().sum().sum()
# Out:
# 780

# %%
#Replacing Unknown values in columns with Null value
df["Revenue"] = df["Revenue"].replace(["Unknown / Non-Applicable"], np.nan)
df["Type of ownership"] = df["Type of ownership"].replace(["Unknown"], np.nan)
df["Size"] = df["Size"].replace(["Unknown"], np.nan)

# %%
# Removing missing values and filtering out invalid salaries
df = df[df["Salary Estimate"].notna() & (df["Salary Estimate"] != "-1")]

# %%
# Cleaning Salary Estimate column
df["Salary Estimate"] = df["Salary Estimate"].str.split("(").str[0]  # Remove text in parentheses
df["Salary Estimate"] = df["Salary Estimate"].str.replace("K", "").str.replace("$", "").str.replace("Per Hour", "").str.replace("Employer Provided Salary:", "").str.strip()

# %%
# Handling salary ranges
def extract_salary(salary_str):
    parts = salary_str.split("-")
    try:
        min_salary = int(parts[0].strip()) if len(parts) > 1 else int(parts[0].strip())
        max_salary = int(parts[1].strip()) if len(parts) > 1 else min_salary
        return (min_salary, max_salary)
    except:
        return (None, None)

df["Min Salary"], df["Max Salary"] = zip(*df["Salary Estimate"].apply(extract_salary))
df = df.dropna(subset=["Min Salary", "Max Salary"])  # Removing invalid rows
df["Avg Salary"] = (df["Min Salary"] + df["Max Salary"]) / 2  # Calculating average salary

# %%
# Grouping by Job Title and calculating the mean salary
top_jobs = df["Job Title"].value_counts().head(10).index  # Selecting top 10 job titles
avg_salary_per_title = df[df["Job Title"].isin(top_jobs)].groupby("Job Title")["Avg Salary"].mean()

# %%
# Grouping by Location and calculating the mean salary
top_locations = df["Location"].value_counts().head(10).index  # Selecting top 10 locations
avg_salary_per_location = df[df["Location"].isin(top_locations)].groupby("Location")["Avg Salary"].mean()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ### Manipulations.
# * Replaced Unknown values in certain columns as null values as they have no essential contribution to the overall datase
# * Removing missing values and filtering out invalid salaries.
# * Cleaning Salary Estimate column.
# * Handling salary ranges
# * Grouping by Job Title and calculating the mean salary
# * Grouping by Location and calculating the mean salary
#   her.
# ### Insights
# The Dataset has a lot of categorical data which could possibly pose a problem while charting and making a predictive algorithm. The Unknown Variables need to be entered null as they have no major contribution. Further Manipulations can/need to be done only if deemed necessary for making a proper predective model.Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# 1. Job Title Distribution (Bar Chart)
plt.figure(figsize=(12, 5))
sns.countplot(y=df["Job Title"], order=df["Job Title"].value_counts().index[:10], palette="viridis")
plt.xlabel("Count")
plt.ylabel("Job Title")
plt.title("Top 10 Most Common Job Titles")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  A bar chart is the ideal choice for displaying categorical distributions (like job titles) because it:
#
# Makes comparisons between categories easy.
# Provides clear and accessible visual representation.
# Works well with a relatively small number of categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Top 10 Most Common Job Titles bar chart provides several valuable insights about the job market based on the dataset. Here's what can be derived from this type of visualization:
#
# 1. The bar chart reveals the most common job titles in the dataset. This shows which roles are highly represented in the job market, such as Data Scientist and Data Engineer.
# 2. The chart helps identify job roles that are growing in demand. For example, if technology-related job titles like Data Engineer or Data Scientist dominate the chart, it reflects a strong demand for these positions in the job market, possibly indicating a tech-focused job market in the given period.
# 3. The relative frequency of each job title helps assess the concentration of the job market around certain roles. If one or two job titles are overwhelmingly dominant, it could indicate a saturated market for those roles. A more balanced distribution across the top 10 titles signals a diverse job market.
# 5. The chart also reveals the specific specializations within broader job titles.
# 6. The certain expected job titles could indicate data bias, missing categories, or a reflection of industry trends where those roles were less prevalent in 2017.
# 8. The chart can also highlight whether certain job roles are over-represented, signaling a competitive or saturated job market. For example, if "Data Engineer" makes up a large portion of the top 10 titles, it suggests a competitive field for that particular role.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact** :
#
# 1. Informed Recruitment Strategy :
#
#  - By understanding the most in-demand job titles, businesses can align their recruitment efforts with market demand.
#
#  - Companies can also focus on targeting talent pools that fit the skill sets of these high-demand roles, improving the efficiency of their hiring process.
#
# 2. Better Workforce Planning :
#
#  - Knowing the dominant job roles helps businesses forecast workforce needs in key areas. If certain roles dominate, a company can plan for future expansion in those departments and avoid over-hiring in less critical areas, thereby improving resource allocation and reducing unnecessary hiring costs.
#
# 3. Strategic Partnerships and Networking :
#
#  - If specific job titles are highly concentrated in certain locations or industries, businesses can form partnerships with educational institutions or professional organizations to create targeted training programs. This helps cultivate the next generation of workers in fields where demand is high, enhancing the company’s long-term talent pipeline.
#
# 4. Improved Employer Branding :
#
#  - Understanding job title distributions can help businesses position themselves as employers of choice. If a company sees that they are already hiring top roles that are in high demand (e.g., "Data Scientists"), they can promote this as part of their employer branding to attract top talent.
#
# **Justification for Negative Growth** :
#
#  - If businesses don’t adapt their hiring practices and focus on emerging roles or specialized skills, they may face a lack of competitive advantage in the long term, as talent in oversaturated fields becomes harder to recruit and retain.
#
#  - Failure to identify growing or underserved job roles can result in businesses being caught off guard by shifts in market demand, leading to a lack of strategic alignment with industry trends and stunted growth in areas that are increasingly important.
#
#  - The narrow Focus on the most common job titles can make companies too homogenous in terms of skills and perspectives, hindering creativity, innovation, and adaptability.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# 2. Average Salary by Job Title (Bar Chart)

# Plotting the bar chart
plt.figure(figsize=(12, 6))
avg_salary_per_title.sort_values().plot(kind="bar", color="seagreen")
plt.title("Average Salary by Job Title")
plt.xlabel("Job Title")
plt.ylabel("Average Salary (in $1000s)")
plt.xticks(rotation=45, ha="right")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart is an effective way to visualize average salaries by job title because it allows for easy comparison between different job roles. The length of each bar clearly represents the salary for each job title, making it simple to identify which roles earn more or less. Since job titles are categorical data, a bar chart is ideal for this type of information, as it efficiently displays and compares multiple categories. Sorting the data helps reveal trends, such as which roles have higher salaries, and makes the chart easier to interpret.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights from the average salary by job title bar chart can include:
#
#
# 1. **High-paying Job Titles**: Certain roles, such as Pricipal Data Scientist and Lead Lead Data Scientist have significantly higher average salaries compared to others. This highlights which job titles are more lucrative and in-demand in the market.
#
# 2. **Low-paying Job Titles**: Roles like Marketing Data Analyst and Data Analyst have lower average salaries, indicating a potential salary gap between entry-level and more specialized positions.
#
# 3. **Salary Gaps**: The visual comparison of salaries can reveal large disparities between certain job titles. If some roles have much higher salaries than others, it may point to inequalities in compensation that could be a focus for businesses aiming to address pay equity.
#
# 4. **Job Market Priorities**: High average salaries for certain roles might reflect the skills and expertise currently most valued in the job market, helping businesses align their recruitment strategies with market demands.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact** : Aligning salaries with industry standards and focusing recruitment on in-demand roles can drive growth, attract top talent, and ensure a competitive edge. It also fosters a healthy work culture and positions the company as an employer of choice.
#
# **Negative Impac**t : However, failing to address the nuances of salary distribution could lead to imbalanced compensation practices, market saturation, and pay equity issues. Overpaying for roles with low long-term value or neglecting lower-paid but essential roles can hinder sustainable growth and employee satisfaction.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# 3. Industry Analysis (Bar Chart)
top_industries = df['Industry'].value_counts().head(10)
top_industries.plot(kind='bar', figsize=(12, 6))
plt.title('Top 10 Industries')
plt.ylabel('Count')
plt.xlabel('Industry')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  The bar chart provides a clear, easy-to-read visualization for comparing job postings across industries, making it ideal for showing the top 10 industries by count.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart provides several key insights into the job market. It highlights which industries are dominating in terms of job postings, with sectors like Boitech and pharmaceuticals as well as insurance often showing higher counts, indicating these fields are experiencing growth and demand for talent. The chart also reveals market demand, with industries that have a high number of job postings signaling active hiring and the need for specific skills. Industries with fewer job postings might indicate gaps in talent or areas that are underrepresented, which could be a focus for skill development or recruitment. Lastly, the chart sheds light on the competitive landscape within industries, as industries with many job postings could indicate higher competition for talent, leading to potentially increased salaries or enhanced employer branding strategies. Overall, the chart serves as a valuable tool for understanding current job market trends, identifying areas of growth, and making informed decisions about talent acquisition or career paths.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact** : The insights help businesses target the right talent, optimize their strategies for growing industries, and stay competitive in an evolving market.
#
# **Negative Impact** : Overemphasizing saturated industries, neglecting niche sectors, or failing to adapt to emerging trends can lead to missed opportunities, increased costs, and hindered growth.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# 4. Top 10 companies with most Job listings (Bar Chart)
if 'Company Name' in df.columns:
    # Count job listings per company
    top_companies = df['Company Name'].value_counts().nlargest(10)  # Top 10 companies

    # Create bar chart
    plt.figure(figsize=(10, 6))
    sns.barplot(x=top_companies.values, y=top_companies.index, palette="Blues_r")

    # Chart formatting
    plt.title("Top 10 Companies with Most Job Listings", fontsize=14, fontweight='bold')
    plt.xlabel("Number of Job Listings", fontsize=12)
    plt.ylabel("Company", fontsize=12)
    plt.grid(axis='x', linestyle='--', alpha=0.7)

    # Show the plot
    plt.show()

else:
  print("The 'Company Name' column is not found in the dataset.")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen because:
#
# - It effectively compares categorical data (companies) with frequency/count data (job listings).
# - It visually displays differences in job listings across companies, making the top 10 stand out clearly.
# - It allows for easy customization and a clear, readable chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Top 10 Companies with the Most Job Listings bar chart provides several key insights:
#
# **1. Dominating Companies**: Companies with the longest bars have the highest number of job listings, indicating they are offering the most opportunities.
#
# **2. Industry Trends**: The chart can reveal which industries are hiring more by showing if certain sectors, such as technology or healthcare, dominate the top 10.
#
# **3. Growth vs. Stability**: Companies with a high number of listings may be in a growth phase, while others with fewer listings may be more stable.
#
# **4. Opportunities for Job Seekers**: The chart helps job seekers identify companies with the most available positions, offering the highest chances for employment.
#
# **5. Outliers**: A company with a significantly higher number of job listings than others may be expanding rapidly or facing unique hiring needs.
#
# This analysis helps understand which companies are most active in recruitment and reveals trends within industries or specific companies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**: The chart helps companies identify growth trends, refine their recruitment strategies, and understand competitive dynamics, all of which can lead to stronger talent acquisition and overall business growth.
#
# **Negative Impact**: However, the chart might also reveal imbalances, like an over-concentration of job listings in a few companies, reduced job opportunities in certain sectors, or over-expansion that might hurt employee satisfaction, leading to potential challenges that could affect long-term growth.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

#5.Job Distribution by Industry (Pie Chart)
if 'Industry' in df.columns:
    # Count the number of job postings per industry
    industry_counts = df['Industry'].value_counts().head(8)

    # Create a pie chart
    plt.figure(figsize=(10, 6))
    plt.pie(industry_counts.values, labels=industry_counts.index, autopct='%1.1f%%',
            startangle=140, colors=plt.cm.Paired.colors)

    # Title and layout
    plt.title("Job Distribution by Industry", fontsize=12, fontweight='bold')
    plt.axis('equal')
    plt.show()
else:
    print("The 'Industry' column is not found in the dataset.")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart was chosen for visualizing the distribution of job postings across industries because it effectively represents the proportional contribution of each industry to the total job market. Each slice of the pie corresponds to a specific industry, with its size reflecting the proportion of job postings in that sector. This makes it easy to see which industries dominate the job market at a glance. The chart is also simple and intuitive, allowing quickly comparison how different industries are represented without needing to interpret complex numbers. Additionally, pie charts are particularly effective for summarizing data and highlighting key trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - **Biotech and Pharmaceuticals** is the dominant sector in terms of job opportunities, highlighting significant growth and demand.
#
# - **Tech and IT sectors**, including Computer Hardware, Software, and IT Services, continue to offer many job opportunities, reflecting the ongoing reliance on technology across industries.
#
# - **Insurance and Healthcare** also represent a large portion of job postings, suggesting that both sectors are in growth mode or facing high demand for services.
#
# This distribution gives insight into which industries are currently driving employment and can help inform job seekers, companies, and analysts about where talent is most needed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**: The insights can help businesses identify growing sectors, optimize hiring strategies in high-demand industries, and position themselves for long-term success by focusing on growth areas like biotech, IT services, and healthcare.
#
# **Negative Impact**: Potential risks include overreliance on a few dominant sectors, stagnation in smaller industries, and the challenges posed by market saturation in industries like insurance and healthcare.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

#6. Company Size vs Revenue Distribution (Heat Map)
if 'Size' in df.columns and 'Revenue' in df.columns:
    # Create a crosstab of company Size vs. Revenue distribution
    size_revenue_ct = pd.crosstab(df['Size'], df['Revenue'])

    # Create a heatmap
    plt.figure(figsize=(12, 8))
    sns.heatmap(size_revenue_ct, annot=True, fmt="d", cmap="viridis")

    # Chart formatting
    plt.title("Company Size vs. Revenue Distribution", fontsize=16, fontweight='bold')
    plt.xlabel("Revenue", fontsize=12)
    plt.ylabel("Company Size", fontsize=12)
    plt.tight_layout()
    plt.show()
else:
    print("Required columns 'Size' and/or 'Revenue' not found in the dataset.")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap is effective because it simplifies complex relationships between company size and revenue into a clear, visually engaging format. It allows for easy identification of trends, patterns, and anomalies, which is crucial for understanding how company size relates to revenue distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Larger companies tend to have higher revenue**: The heatmap likely shows a higher concentration of large companies in the higher revenue categories, which is expected as they have more resources and market reach.
#
# 2. **Mid-sized companies can perform well**: Some mid-sized companies may be found in higher revenue categories, suggesting that size alone doesn't always limit revenue potential.
#
# 3. **Smaller companies are concentrated in lower revenue categories**: Smaller companies are more likely to be clustered in lower revenue ranges, indicating challenges in scaling or limited resources.
#
# 4. **Outliers in small companies**: Small companies in higher revenue categories may point to exceptional business models or specific industries where small businesses can succeed.
#
# 5. **Variability in performance**: Even within the same company size, revenue levels can vary, indicating that factors like efficiency, market strategy, and competitive advantage play significant roles in revenue generation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights from the heatmap can positively influence business growth by identifying opportunities to scale mid-sized and small companies, targeting investments in high-growth areas, and supporting innovation. However, the data also highlights challenges such as stagnation in small companies, an overfocus on large companies, and potential market saturation, all of which could contribute to negative growth if not addressed strategically.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# 7. Founded by Rating (Scatterplot)
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["Founded"], y=df["Rating"], alpha=0.6, color="blue")
plt.xlabel("Year Founded")
plt.ylabel("Company Rating")
plt.title("Company Rating vs. Year Founded")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The scatter plot is an effective tool for analyzing the relationship between company age and ratings, as it provides clear visual cues for identifying patterns, outliers, and trends, making it a powerful tool for data analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Concentration of Companies in Recent Years**:
#
# -  Most companies are founded after the 1700s, with a significant cluster appearing after the 1900s.
#
# -  Very few companies were founded before 1700, but they still have ratings.
#
# 2. **Outliers in the Data**:
#
# -  Some companies have a negative rating (below 0), which could be an error or missing data issue.
#
# -  Some companies have been assigned a year close to 0, which might be due to missing or incorrect data.
#
# 3. **Ratings Distribution Across Time**:
#
# -  Companies founded in more recent years (1900s–2000s) have ratings ranging from 2 to 5, with a dense cluster around 3 to 4.
# -  Older companies (before 1800) also have varied ratings, but there are fewer data points.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# -  Errors in founding years and negative ratings indicate unreliable data, which can mislead business decisions.
#
# -  Older companies may struggle with adaptation, and their lower ratings could signal stagnation or loss of market relevance.
# -  A high concentration of well-rated companies in recent years suggests market saturation, making it harder for new businesses to differentiate themselves.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# 8. Job Title vs. Company Rating (Boxplot)
plt.figure(figsize=(12, 6))
top_jobs = df["Job Title"].value_counts().index[:5]  # Top 5 jobs
sns.boxplot(x=df[df["Job Title"].isin(top_jobs)]["Job Title"], y=df["Rating"])
plt.xlabel("Job Title")
plt.ylabel("Company Rating")
plt.title("Company Ratings for Different Job Titles")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The box plot is useful for analyzing central tendencies, variation, and outliers in company ratings across different job titles, helping to gain insights into job satisfaction and potential workplace trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Senior Data Scientist and Senior Data Engineer have higher median ratings compared to Data Scientist and Data Engineer, indicating better job satisfaction in senior roles.
#
# 2. Data Engineers show a wider spread of ratings, suggesting mixed experiences among employees.
#
# 3. Data Analysts tend to have a lower median rating compared to other roles, indicating varying job satisfaction levels.
#
# 4. Outliers in the ratings suggest that some employees had significantly different experiences, either highly positive or negative.
#
# 5. Senior roles generally have more stable and higher ratings, possibly due to better compensation, experience, or job stability.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights can drive positive business impact by improving job satisfaction and retention. Higher ratings for senior roles suggest investing in career growth programs, while lower ratings for Data Analysts highlight areas for improvement in workload and compensation. The wide rating spread for Data Engineers indicates inconsistent experiences, requiring better work conditions. Ignoring these insights may lead to higher turnover and lower productivity. Addressing these issues helps create a strong work culture, attract talent, and ensure long-term business success.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# 9. Number of companies in each sector (Barplot)
# Count number of companies in each sector
sector_counts = df["Sector"].value_counts()
plt.figure(figsize=(12, 6))
sns.barplot(x=sector_counts.values, y=sector_counts.index, color="skyblue")
plt.xlabel("Number of Companies")
plt.ylabel("Sector")
plt.title("Number of Companies in Each Sector")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The horizontal bar chart is selected because it effectively displays the number of companies in each sector, making it easy to compare different industries.
#
# It provides clear visibility of how industries vary in company distribution, showing which sectors dominate and which have fewer companies. The sorted structure ensures that the largest and smallest sectors are easily distinguishable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Information Technology dominates** with the highest number of companies, indicating strong industry growth and high demand for tech-related services.
# 2. **Biotech & Pharmaceuticals and Business Services** are also prominent, suggesting significant investment and expansion in healthcare and corporate solutions.
# 3. **Insurance, Health Care, and Finance sectors** have a substantial presence, highlighting their importance in economic stability and risk management.
# 4. **Industries like Accounting & Legal, Agriculture & Forestry, and Construction & Repair** have the fewest companies, suggesting either lower demand, higher entry barriers, or niche specialization.
#
# 5. **Manufacturing and Aerospace & Defense show moderate company presence,** reflecting a mix of industrial demand and specialized expertise requirements.
#
# 6. **Retail, Oil & Gas, and Government sectors have a smaller share,** possibly indicating consolidation or limited new entrants in these industries.
#
# The overall distribution suggests technology-driven sectors are growing, while traditional industries may have slower expansion or require higher investment to compete.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights help identify high-growth sectors like **Information Technology, Biotech & Pharmaceuticals, and Business Services,** making them ideal for investment and expansion. Moderate presence in **Finance, Health Care, and Manufacturing** indicates stable markets with growth potential.
#
# Negative growth risks exist in sectors with fewer companies, such as **Accounting & Legal, Agriculture & Forestry, and Construction & Repair,** possibly due to high entry barriers or low demand. **Retail, Oil & Gas, and Government sectors** may face stagnation or limited scalability.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

#10. Employee Size Count (Bar Chart)
size_counts = df["Size"].value_counts()
plt.figure(figsize=(12, 6))
sns.barplot(y=size_counts.index, x=size_counts.values, palette="viridis")
plt.xlabel("Number of Companies")
plt.ylabel("Employee Size Category")
plt.title("Distribution of Companies by Employee Size")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chart effectively visualizes the distribution of companies based on employee size, making it easier to identify the most common company sizes. The horizontal bar format allows for clear comparison across different categories, showing which employee size segments dominate the dataset. Larger companies, such as those with **1001 to 5000 employees,** are more prevalent, while smaller companies with **1 to 50 employees** are fewer in number. This type of visualization is useful for workforce planning, business strategy, and understanding industry employment trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Mid-sized to large companies (1001 to 5000 employees) dominate,** indicating strong growth and stability in this segment.
#
# 2. **Significant presence of companies with 501 to 1000 employees and 10,000+ employees**, showing a mix of scaling businesses and established enterprises.
#
# 3. **Small companies (1 to 50 employees) are the least represented**, suggesting challenges in sustainability and growth.
#
# 4. **Fewer companies in the 5001 to 10,000 employee range**, implying potential difficulties in scaling beyond mid-size.
#
# 5. **The distribution highlights workforce trends**, helping businesses with strategic planning, market positioning, and talent acquisition.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can help create a **positive business impact** by guiding companies in **workforce planning, market positioning, and scaling strategies.** Understanding that mid-sized companies dominate can help businesses **align their growth strategies**, invest in talent acquisition, and identify **industry trends** for expansion. Large organizations can use this data to **optimize operations and maintain competitiveness**
#
# However, the insights also highlight **potential challenges leading to negative growth. The low presence of small businesses (1 to 50 employees)** suggests difficulties in sustaining operations, securing funding, or scaling beyond a certain level. Similarly, **fewer companies in the 5001 to 10,000 employee range** indicate possible barriers in transitioning from mid-size to large enterprises, such as **higher operational costs, regulatory hurdles, or management inefficiencies**. Addressing these challenges is crucial for long-term success.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

#11. Job Locations (Top 10 Cities) (Barchart)
df["City"] = df["Location"].apply(lambda x: x.split(",")[0])
plt.figure(figsize=(8, 6))
top_cities = df["City"].value_counts().nlargest(10)
sns.barplot(x=top_cities.values, y=top_cities.index)
plt.title("Top 10 Cities with Most Job Listings")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart effectively displays job listings across the top 10 cities, making it easy to compare job availability in different locations. The clear labels and structured format allow quick identification of cities with the highest job opportunities. The length of each bar visually represents the number of job postings, ensuring an intuitive understanding of the data. This type of visualization is particularly useful when comparing multiple categories, as it prevents overcrowding and maintains readability.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **New York** has the highest number of job listings, indicating strong employment opportunities.
#
# 2. **San Francisco and Cambridge** follow closely, suggesting a concentration of jobs in tech and business sectors.
#
# 3. **Chicago and Boston** also have significant job listings, reflecting their diverse job markets.
#
# 4. The remaining cities, including **San Jose, Pittsburgh, Rockville, Washington, and Winston-Salem**, have fewer job postings but still represent key employment hubs.
#
# 5. The distribution suggests job opportunities are concentrated in major metropolitan areas, likely due to economic activity, industry presence, and infrastructure.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The insights can help businesses expand into high-demand job markets like New York, San Francisco, and Cambridge, attracting top talent and increasing revenue.
#
# - Companies can use this data to target recruitment efforts in cities with high job listings, optimizing hiring strategies and workforce distribution.
#
# - A high concentration of job listings in specific cities indicates strong economic growth, encouraging business investments in those regions.
#
# - **Negative growth** may occur in cities with fewer job opportunities, potentially leading to talent migration and economic decline.
#
# - Companies operating in cities with low job postings might struggle to attract skilled professionals, impacting productivity and innovation.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# 12. Distribution of Type of Ownership Across Sectors (Bar Chart)
# Count the number of companies by Sector and Type of Ownership
sector_ownership_counts = df.groupby(["Sector", "Type of ownership"]).size().unstack()
sector_ownership_counts.plot(kind="bar", stacked=True, figsize=(14, 6), colormap="afmhot")
plt.xlabel("Sector")
plt.ylabel("Number of Companies")
plt.title("Distribution of Type of Ownership Across Sectors")
plt.xticks(rotation=45, ha='right')
plt.legend(title="Type of Ownership")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart effectively visualizes the distribution of different types of ownership across various industry sectors, making it easier to identify trends and patterns. The stacked bar format allows for a direct comparison of ownership structures, highlighting which industries have a dominance of private, public, government, nonprofit, or other organizational types. This approach is particularly useful for businesses and policymakers to assess industry dynamics, investment opportunities, and sector-specific employment trends. The color-coded legend further enhances clarity by differentiating ownership categories, enabling quick interpretation of sectoral ownership distributions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Dominance of Private Companies** – Most industries are primarily composed of private companies, especially in sectors like Information Technology, Business Services, and Manufacturing. This indicates that private enterprises play a significant role in driving these industries.
#
#
# 2. **High Presence of Public Companies in Key Sectors** – Public companies have a notable presence in Business Services, Information Technology, and Manufacturing, suggesting these sectors attract significant investments and have large-scale operations.
#
#
# 3. **Government and Nonprofit Organizations in Specific Sectors** – Sectors like Health Care, Education, and Government have a mix of nonprofit organizations, hospitals, and government institutions, showing a strong public sector influence in these fields.
#
#
# 4. **Sector-Specific Ownership Trends** – Some industries like Aerospace & Defense, Finance, and Biotech & Pharmaceuticals have a diverse ownership mix, indicating both private and government involvement, which may be driven by regulatory requirements and funding structures.
#
#
# 5. **Limited Representation in Certain Sectors** – Industries like Arts, Entertainment & Recreation, Agriculture & Forestry, and Oil, Gas & Energy have fewer companies listed, possibly indicating lower employment opportunities or specialized market entry barriers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# 1. **Strategic Investment Decisions** – High concentration of private companies in IT, Business Services, and Manufacturing indicates strong growth potential, making these sectors attractive for investment.
#
# 2. **Government and Nonprofit Opportunities** – The presence of hospitals, schools, and nonprofits in Health Care and Education opens opportunities for service providers, software developers, and infrastructure businesses.
#
# 3. **Expansion and Market Entry** – Companies can use ownership trends to identify industries with strong public or private investment, helping them plan expansion strategies effectively.
#
# **Negative Growth Factors and Justification:**
#
# 1. **Industry Concentration Risk** – A high number of private companies in key industries may limit competition, making it harder for new businesses to enter.
#
# 2. **Limited Growth in Some Sectors** – Sectors like Agriculture, Arts, and Oil & Gas have fewer companies, which may indicate slow growth, high entry barriers, or declining demand.
#
# 3. **Government Dependency Risks** – Sectors like Health Care and Education depend on government policies, funding, and regulations, which could create financial instability if policies change.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# 13. Type od ownership vs. Company Rating (Scatterplot)
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["Rating"], y=df["Type of ownership"], alpha=0.6)
plt.xlabel("Company Rating")
plt.ylabel("Type of ownership")
plt.title("Relationship Between Type of ownership and Company Rating")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This scatter plot was chosen to visualize the relationship between company ownership types and their ratings. It helps identify patterns in how different types of organizations are rated, revealing whether private, public, or nonprofit organizations tend to receive higher or lower ratings. By displaying individual data points, the chart allows for a clear comparison of rating distributions across ownership types, aiding in decision-making for job seekers, investors, or policymakers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Private Companies Have a Wide Rating Range** – Private companies show a broad distribution of ratings, from very low (near 1) to very high (close to 5), suggesting varied employee experiences.
#
# 2. **Public Companies Have Relatively High Ratings** – Many public companies are clustered around ratings of 3 to 4.5, indicating generally favorable reviews.
#
# 3. **Nonprofit Organizations and Educational Institutions Show Moderate Ratings** – Colleges, universities, and nonprofit organizations mostly have ratings between 3 and 4, reflecting stable but not exceptional satisfaction.
#
# 4. **Government and Subsidiary Organizations Have Mixed Ratings** – Some government organizations have lower ratings, while others perform well, implying inconsistency in employee satisfaction.
#
# 5. **Hospitals and Healthcare Organizations Show Moderate to High Ratings** – Many healthcare institutions have ratings around 3.5 to 4, suggesting a decent work environment.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can help create a **positive business impact** by allowing companies to understand employee satisfaction trends across different ownership types. Private and public companies with high ratings can leverage their positive reputation to attract top talent, while organizations with lower ratings can focus on improving workplace conditions, benefits, and policies to enhance employee retention and productivity. Nonprofit and educational institutions, which mostly have moderate ratings, can work on improving employee engagement and incentives to boost satisfaction.
#
# On the **negative side**, companies with consistently low ratings may struggle with talent acquisition and retention, leading to increased hiring costs and decreased productivity. Government and some private organizations with lower ratings may indicate dissatisfaction due to job security concerns, lack of career growth, or poor work culture. If these issues are not addressed, they could result in higher turnover rates and reduced overall business performance.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# 14. Correlation Heatmap
plt.figure(figsize=(10, 6))
corr = df.select_dtypes(include=['number']).corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This heatmap was chosen because it visually represents the correlation between numerical features, making it easy to identify strong relationships. It highlights which variables have high positive or negative correlations, helping in decision-making. For example, salaries (Min, Max, and Avg) are highly correlated with each other, indicating a strong relationship. Meanwhile, ratings have a weak correlation with salaries, suggesting that salary alone may not determine employee satisfaction. The heatmap helps in feature selection for predictive modeling and provides insights into key business factors affecting job ratings and salaries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap provides several key insights:
#
# 1. **Strong correlation between salary components** – Min Salary, Max Salary, and Avg Salary have values close to 1, indicating that these factors move together. If one increases, the others are likely to increase as well.
#
#
# 2. **Weak correlation between Rating and Salary** – The correlation between company rating and salaries is very low (close to 0), suggesting that higher salaries do not necessarily lead to better company ratings. Other factors like work culture, benefits, and job security may play a bigger role in employee satisfaction.
#
#
# 3. **No significant relationship between company founding year and other variables** – The "Founded" column has near-zero correlation with salaries and ratings, implying that a company's age does not strongly impact salaries or employee satisfaction.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# 15. Pair Plot
numerical_cols = df.select_dtypes(include=['number']).columns
sns.pairplot(df[numerical_cols])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is chosen because:
#
# 1. **Visualizes Relationships**: It helps identify relationships between multiple numerical variables at once.
#
# 2. **Detects Trends & Correlations**: Scatter plots show if variables have a positive, negative, or no correlation.
#
# 3. **Identifies Outliers**: Extreme data points stand out, helping detect outliers.
#
# 4. **Shows Data Distribution**: The diagonal plots show histograms or KDE plots, revealing how each variable is distributed.
#
# 5. **Explores Clusters**: It can hint at natural groupings in the data, useful for classification or segmentation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot provides the following insights:
#
# 1. **Variable Relationships**: It reveals the correlations between different numerical variables, such as salary, rating, and company attributes.
#
# 2. **Trends & Patterns**: If there is a linear trend in scatter plots, it indicates a strong relationship between two variables.
#
# 3. **Outliers Detection**: Any extreme points deviating from the trend may highlight unusual cases.
#
# 4. **Clusters or Groups**: If data points naturally form groups, it suggests segmentation in the dataset, which may be useful for targeted analysis.
#
# 5. **Distribution of Variables**: The diagonal plots show how each numerical feature is distributed, helping understand skewness or normality.
#
# These insights can guide further analysis, model selection, or business strategies.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve business objectives based on the **Glassdoor Jobs 2017** data analysis, the client should focus on **high-demand job locations** to improve hiring efficiency. Offering **competitive salaries** is crucial since salary levels strongly correlate with each other. Improving **company ratings** through better work culture and benefits will enhance employer branding.
#
# Prioritizing **growing industries like Technology, Healthcare, and Business Services** ensures higher job placements. At the same time, monitoring **declining sectors** helps avoid unnecessary investments. Enhancing the **candidate experience** with a smooth hiring process and leveraging AI recruitment tools will improve talent acquisition.
#
# Regular **data-driven decision-making** will help optimize recruitment strategies, leading to **better market positioning and business growth.**

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis of **Glassdoor Jobs 2017** data provides valuable insights into job trends, salaries, company ratings, and industry growth. Key findings suggest that **technology, healthcare, and business services** are the dominant industries with the highest job availability. **Competitive salaries and higher company ratings** are critical factors in attracting top talent, and businesses should focus on improving employee satisfaction to enhance employer branding.
#
# Job availability is concentrated in specific **high-demand locations**, meaning companies should strategically **target these cities** for recruitment efforts. The strong correlation between **minimum, maximum, and average salaries** emphasizes the need for well-structured compensation plans to remain competitive.
#
# To drive **business success**, organizations should focus on **data-driven hiring strategies, industry trends, and employee experience enhancements**. Implementing **AI-driven recruitment tools, optimizing job listings, and improving work culture** will lead to sustainable growth and better market positioning in the competitive job landscape.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
